# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path_to_file ='C:/Users/etusk/Documents/wellcome.csv'
data = pd.read_csv(path_to_file)
data.describe()
# Out:
#        PMID/PMCID Publisher Journal title  \
# count        1928      2127          2126
# unique       1880       299           984
# top             -  Elsevier      PLoS One
# freq            7       387            92
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     Exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                2127
# unique                                               1402
# top                                              £2040.00
# freq                                                   94

# %%
#Renaming Columns for simplicity 
data.columns = ['ID', "Publisher", 'Journal', 'Title', 'Cost']
#Get rid of unecessary columns 
df= data.drop(['ID','Publisher'], axis=1)
#Review data again
df.describe()
# Out:
#          Journal                                              Title      Cost
# count       2126                                               2127      2127
# unique       984                                               2126      1402
# top     PLoS One  Exclusive breastfeeding, diarrhoel morbidity a...  £2040.00
# freq          92                                                  2        94

# %%
#Get rid of pound symbol
x=datacolumns2['Cost'].str.split('£', expand=True)
x=x.loc[:,1].to_list()
df['Cost2'] = x #why won't this let me convert the data into a column - orignal value was a df and needed to be converted to a list. using types

# %%
#Makes all Journal titles lower case 
lowercase = df['Journal'].astype(str) 
df['lowercase_Journal']=lowercase.str.lower()
df['lowercase_Journal'].value_counts().max
# Out:
#   File "<ipython-input-80-e9980fa7da7a>", line 9
#     #Plos 1' in lowercase.index Does this help us find a value in a df?
#                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
#Remove Whitespace
df['drop_Journal'] = df['lowercase_Journal'].str.strip()

# %%
#Remove Null and NA values 
df.dropna()
# Out:
#                                                 Journal  \
# 0                                Psychological Medicine
# 1                                     Biomacromolecules
# 2                                            J Med Chem
# 3                                            J Med Chem
# 4                                            J Org Chem
# 5                        Journal of Medicinal Chemistry
# 6                          Journal of Proteome Research
# 7                                             Mol Pharm
# 8                                  ACS Chemical Biology
# 9                                  ACS Chemical Biology
# 10         Journal of Chemical Information and Modeling
# 11                       Journal of Medicinal Chemistry
# 12                       Journal of Medicinal Chemistry
# 13                                         Biochemistry
# 14                       Journal of Medicinal Chemistry
# 15                                     Gastroenterology
# ...

# %%
#Get the mean, median, mode, and SD for each Journal
#Group by Journal 
df['Cost2']=df['Cost2'].astype(float)
df.groupby('drop_Journal')['Cost2'].mean()
# Out:
# drop_Journal
# academy of nutrition and dietetics                                                           2379.540000
# acs chemical biology                                                                         1418.186000
# acs chemical neuroscience                                                                    1186.800000
# acs nano                                                                                      668.140000
# acta crystallographica section d,  biological crystallography                                 771.420000
# acta crystallographica section d: biological crystallography                                  773.740000
# acta crystallographica section f: structural biology and crystallization communications       796.635000
# acta crystallographica, section d                                                             757.180000
# acta crystallography d                                                                        774.190000
# ...

# %%
df.groupby('drop_Journal')['Cost2'].median()
# Out:
# drop_Journal
# academy of nutrition and dietetics                                                           2379.540
# acs chemical biology                                                                         1294.590
# acs chemical neuroscience                                                                    1186.800
# acs nano                                                                                      668.140
# acta crystallographica section d,  biological crystallography                                 771.420
# acta crystallographica section d: biological crystallography                                  773.740
# acta crystallographica section f: structural biology and crystallization communications       796.635
# acta crystallographica, section d                                                             757.180
# acta crystallography d                                                                        774.190
# ...

# %%
df.groupby('drop_Journal')['Cost2'].std()
#df['Cost2'].dtype
# Out:
# drop_Journal
# academy of nutrition and dietetics                                                                   NaN
# acs chemical biology                                                                          507.309560
# acs chemical neuroscience                                                                            NaN
# acs nano                                                                                       35.708892
# acta crystallographica section d,  biological crystallography                                        NaN
# acta crystallographica section d: biological crystallography                                         NaN
# acta crystallographica section f: structural biology and crystallization communications        15.605847
# acta crystallographica, section d                                                                    NaN
# acta crystallography d                                                                               NaN
# ...

# %%
#print(df.head())
df.loc[df['lowercase_Journal'] == 'virus research'] #Works to find individual values
# Out:
#             Journal                                              Title Cost  \
# 827  Virus Research  Prostratin exhibits both replication enhancing...
#
#     lowercase_Journal    drop_Journal    Cost2
# 827    virus research  virus research  1947.09

# %%
#final table
df2= df.drop("Journal", axis=1) #axis = 0 is rows; axis=1 is columns

# %%
df2.loc[df['lowercase_Journal'] == 'plos 1'] 
df['lowercase_Journal'] = df['lowercase_Journal'].apply(lambda x: x.replace('plos 1', 'plos one'))
#def int_to_en(num):
    #d={1 : "One"} #Takes care of Plos 1 
    #assert(0<=num)

# %%
df2.loc[df['lowercase_Journal'] == 'plos one']
# Out:
#                                                   Title Cost  \
# 1282  HCN1 and HCN2 in Rat DRG Neurons: Levels in No...
# 1283  Fetal alcohol exposure and IQ at age 8: Eviden...
# 1284  Vitamin B-12 status during pregnancy and child...
# 1285  Validation of Dual Energy X-ray Absorptiometry...
# 1286  Associations of different phenotypes of wheezi...
# 1287  "Involvement of EphB1 receptors signalling in ...
# 1288  Reactive oxygen species modulate the barrier f...
# 1289  Chronic pravastatin but not atorvastatin treat...
# 1290  Expression of HIV-1 Vpu Leads to Loss of the V...
# 1291  Molecular phylogeny of a RING E3 ubiquitin lig...
# 1292  Anti-Müllerian hormone is not associated with ...
# 1293  A Method for Positive and Negative Selection o...
# 1294  On the importance of countergradients for the ...
# 1295  Telomeric repeats facilitate CENP-ACnp1 incorp...
# 1296  The effect of anti-rosetting agents against ma...
# 1297  Modification of the FoxP3 transcription factor...
# ...
